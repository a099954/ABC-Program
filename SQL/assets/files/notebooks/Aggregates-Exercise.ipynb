-- %% [markdown]
-- # Aggregates Exercise
--
-- In this exercise, you will be taking all of the knowledge from the Aggregates lesson and applying it by writing queries to answer questions about the data. For this exercise, we are using the WideWorldImporters database. Answer these questions with a query using the keywords in the Aggregates lesson.

-- %%
USE WideWorldImporters
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.031

-- %% [markdown]
-- What is the average typical weight per unit for warehouse stock items?

-- %%
-- What is the average typical weight per unit for warehouse stock items? 
SELECT AVG(TypicalWeightPerUnit) FROM Warehouse.StockItems
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.017
-- <table><tr><th>(No column name)</th></tr><tr><td>1.833920</td></tr></table>

-- %% [markdown]
-- What are the heaviest and lightest stock items - based on typical weight per unit? Use SQL variables to store the heaviest and lightest values. Then select the items based on those values.

-- %%
-- What are the heaviest and lightest stock items - based on typical weight per unit?
-- Use SQL variables to store the minimum and maximum values.
-- Then build a query off of those results.

DECLARE @HeaviestWeight decimal(18,3)
DECLARE @LightestWeight decimal(18,3)

SELECT @HeaviestWeight = MAX(TypicalWeightPerUnit), @LightestWeight = MIN(TypicalWeightPerUnit) FROM Warehouse.StockItems

SELECT StockItemName, TypicalWeightPerUnit 
FROM Warehouse.StockItems 
WHERE TypicalWeightPerUnit = @HeaviestWeight OR TypicalWeightPerUnit = @LightestWeight
-- Out:
-- (11 rows affected)
-- Total execution time: 00:00:00.013
-- <table><tr><th>StockItemName</th><th>TypicalWeightPerUnit</th></tr><tr><td>USB food flash drive - sushi roll</td><td>0.050</td></tr><tr><td>USB food flash drive - hamburger</td><td>0.050</td></tr><tr><td>USB food flash drive - hot dog</td><td>0.050</td></tr><tr><td>USB food flash drive - pizza slice</td><td>0.050</td></tr><tr><td>USB food flash drive - banana</td><td>0.050</td></tr><tr><td>USB food flash drive - chocolate bar</td><td>0.050</td></tr><tr><td>USB food flash drive - cookie</td><td>0.050</td></tr><tr><td>USB food flash drive - donut</td><td>0.050</td></tr><tr><td>USB food flash drive - shrimp cocktail</td><td>0.050</td></tr><tr><td>USB food flash drive - fortune cookie</td><td>0.050</td></tr><tr><td>Ride on big wheel monster truck (Black) 1/12 scale</td><td>21.000</td></tr></table>

-- %% [markdown]
-- Create a list of brands and their count of stock items in the warehouse. Sort it by the most items items to least items, then alphabetical by brand.

-- %%
-- Create a list of brands and their total stock items in the warehouse. Sort it by the most items items to least items, then alphabetical by brand.
SELECT Brand, Count(StockItemID) AS StockItemCount
FROM Warehouse.StockItems
GROUP BY Brand
ORDER BY StockItemCount DESC, Brand
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.012
-- <table><tr><th>Brand</th><th>StockItemCount</th></tr><tr><td>NULL</td><td>209</td></tr><tr><td>Northwind</td><td>18</td></tr></table>

-- %% [markdown]
-- How many temperature sensor recordings are there for the vehicle temperatures? When was the earliest one? When was the latest one?

-- %%
-- How many temperature sensor recordings are there for the vehicle temperatures? 
SELECT COUNT(VehicleTemperatureID) AS TemperatureCount, MIN(RecordedWhen) AS EarliestDate, MAX(RecordedWhen) AS LatestDate
FROM Warehouse.VehicleTemperatures
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.062
-- <table><tr><th>TemperatureCount</th><th>EarliestDate</th><th>LatestDate</th></tr><tr><td>65998</td><td>2016-01-01 07:00:00.0000000</td><td>2016-05-31 15:57:19.0000000</td></tr></table>

-- %% [markdown]
-- Now that we understand how many records we are working with and what date range is recorded, let's get a bit more specific.
--
-- Get the VehicleRegistration, ChillerSensorNumber, Min temperature, Max temperature, Average temperature, number of readings, and number of unique vehicle registrations for the month of March 2016. Order by vehicle registration and chiller sensor number.

-- %% [markdown]
-- <br>

-- %%
-- Get the VehicleRegistration, ChillerSensorNumber, Min temperature, Max temperature,  Average temperature, number of readings, and number of unique vehicle registrations for the month of March 2016.  Order by vehicle registration and chiller sensor number.
-- The date range makes a difference for the BETWEEN and <= and >= ranges.
-- You can get those specific values from MIN and MAX RecordedWhen values.

SELECT VehicleRegistration, ChillerSensorNumber, MIN(Temperature) AS MinTemperature, MAX(Temperature) AS MaxTemperature, AVG(Temperature) AS AverageTemperature, COUNT(VehicleTemperatureID) AS NumberOfReadings,COUNT(DISTINCT VehicleRegistration) AS NumberOfVehicles
FROM Warehouse.VehicleTemperatures
WHERE YEAR(RecordedWhen) = 2016 AND MONTH(RecordedWhen) = 3
GROUP BY VehicleRegistration, ChillerSensorNumber
ORDER BY VehicleRegistration, ChillerSensorNumber

SELECT VehicleRegistration, ChillerSensorNumber, MIN(Temperature) AS MinTemperature, MAX(Temperature) AS MaxTemperature, AVG(Temperature) AS AverageTemperature, COUNT(VehicleTemperatureID) AS NumberOfReadings,COUNT(DISTINCT VehicleRegistration) AS NumberOfVehicles
FROM Warehouse.VehicleTemperatures
WHERE RecordedWhen BETWEEN '2016-03-01 00:00:00.0000000' AND '2016-03-31 23:59:59.9999999'
GROUP BY VehicleRegistration, ChillerSensorNumber
ORDER BY VehicleRegistration, ChillerSensorNumber

SELECT VehicleRegistration, ChillerSensorNumber, MIN(Temperature) AS MinTemperature, MAX(Temperature) AS MaxTemperature, AVG(Temperature) AS AverageTemperature, COUNT(VehicleTemperatureID) AS NumberOfReadings,COUNT(DISTINCT VehicleRegistration) AS NumberOfVehicles
FROM Warehouse.VehicleTemperatures
WHERE RecordedWhen >= '2016-03-01 00:00:00.0000000' AND RecordedWhen <= '2016-03-31 23:59:59.9999999'
GROUP BY VehicleRegistration, ChillerSensorNumber
ORDER BY VehicleRegistration, ChillerSensorNumber
-- Out:
-- (2 rows affected)
-- (2 rows affected)
-- (2 rows affected)
-- Total execution time: 00:00:00.207
-- <table><tr><th>VehicleRegistration</th><th>ChillerSensorNumber</th><th>MinTemperature</th><th>MaxTemperature</th><th>AverageTemperature</th><th>NumberOfReadings</th><th>NumberOfVehicles</th></tr><tr><td>WWI-321-A</td><td>1</td><td>3.00</td><td>5.00</td><td>4.001882</td><td>6757</td><td>1</td></tr><tr><td>WWI-321-A</td><td>2</td><td>3.00</td><td>5.00</td><td>4.008250</td><td>6757</td><td>1</td></tr></table>
-- <table><tr><th>VehicleRegistration</th><th>ChillerSensorNumber</th><th>MinTemperature</th><th>MaxTemperature</th><th>AverageTemperature</th><th>NumberOfReadings</th><th>NumberOfVehicles</th></tr><tr><td>WWI-321-A</td><td>1</td><td>3.00</td><td>5.00</td><td>4.001882</td><td>6757</td><td>1</td></tr><tr><td>WWI-321-A</td><td>2</td><td>3.00</td><td>5.00</td><td>4.008250</td><td>6757</td><td>1</td></tr></table>
-- <table><tr><th>VehicleRegistration</th><th>ChillerSensorNumber</th><th>MinTemperature</th><th>MaxTemperature</th><th>AverageTemperature</th><th>NumberOfReadings</th><th>NumberOfVehicles</th></tr><tr><td>WWI-321-A</td><td>1</td><td>3.00</td><td>5.00</td><td>4.001882</td><td>6757</td><td>1</td></tr><tr><td>WWI-321-A</td><td>2</td><td>3.00</td><td>5.00</td><td>4.008250</td><td>6757</td><td>1</td></tr></table>

-- %% [markdown]
-- For the Sales Orders, we want to know the final sums for each order, sorted on order total. An order line's total can be calculated as: (Quantity * UnitPrice) + (Quantity * UnitPrice * TaxRate/100)
--
-- Let's start by looking at the order lines for Order 1163

-- %%
-- Let's start by looking at the order lines for Order 1163
SELECT * FROM Sales.OrderLines WHERE OrderID = 1163
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.012
-- <table><tr><th>OrderLineID</th><th>OrderID</th><th>StockItemID</th><th>Description</th><th>PackageTypeID</th><th>Quantity</th><th>UnitPrice</th><th>TaxRate</th><th>PickedQuantity</th><th>PickingCompletedWhen</th><th>LastEditedBy</th><th>LastEditedWhen</th></tr><tr><td>3577</td><td>1163</td><td>138</td><td>Furry animal socks (Pink) S</td><td>10</td><td>36</td><td>5.00</td><td>15.000</td><td>36</td><td>2013-01-23 11:00:00.0000000</td><td>20</td><td>2013-01-23 11:00:00.0000000</td></tr><tr><td>3578</td><td>1163</td><td>141</td><td>Furry animal socks (Pink) XL</td><td>10</td><td>72</td><td>5.00</td><td>15.000</td><td>72</td><td>2013-01-23 11:00:00.0000000</td><td>20</td><td>2013-01-23 11:00:00.0000000</td></tr></table>

-- %% [markdown]
-- Now let's get the total for these order lines for Order 11663

-- %%
-- Now let's get the total for these order lines for Order 11663
SELECT OrderID, SUM((Quantity * UnitPrice) + (Quantity * UnitPrice * TaxRate/100))
FROM Sales.OrderLines
WHERE OrderID = 1163
GROUP BY OrderID
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.018
-- <table><tr><th>OrderID</th><th>(No column name)</th></tr><tr><td>1163</td><td>621.000000</td></tr></table>

-- %% [markdown]
-- There is a PickedQuantity table on the OrderLines. Are there any orders where Quantity and PickedQuantity don't match? Let's count the order lines

-- %%
-- Are there any orders where Quantity and PickedQuantity don't match? Let's count the order lines
SELECT COUNT(OrderLineID) FROM Sales.OrderLines WHERE Quantity != PickedQuantity
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.015
-- <table><tr><th>(No column name)</th></tr><tr><td>3147</td></tr></table>

-- %% [markdown]
-- Let's see what orders have outstanding quantities and how many quantites are still outstanding for each order.

-- %%
-- Let's see what orders have outstanding quantities and how many quantites are still outstanding for each order.
SELECT OrderID, SUM(Quantity-PickedQuantity) AS OutstandingQuantity
FROM Sales.OrderLines
WHERE Quantity <> PickedQuantity
GROUP BY OrderID
-- Out:
-- (3085 rows affected)
-- Total execution time: 00:00:00.067
-- <table><tr><th>OrderID</th><th>OutstandingQuantity</th></tr><tr><td>7770</td><td>120</td></tr><tr><td>20013</td><td>120</td></tr><tr><td>23107</td><td>120</td></tr><tr><td>24731</td><td>120</td></tr><tr><td>32372</td><td>120</td></tr><tr><td>35381</td><td>240</td></tr><tr><td>61752</td><td>120</td></tr><tr><td>61820</td><td>120</td></tr><tr><td>71401</td><td>120</td></tr><tr><td>7906</td><td>120</td></tr><tr><td>36429</td><td>120</td></tr><tr><td>45174</td><td>120</td></tr><tr><td>1785</td><td>120</td></tr><tr><td>16509</td><td>120</td></tr><tr><td>57543</td><td>120</